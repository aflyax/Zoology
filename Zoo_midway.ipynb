# %%
#Import libraries for doing image analysis
from skimage.io import imread
from skimage.transform import resize
from sklearn.ensemble import RandomForestClassifier as RF
import glob
import os
from sklearn import cross_validation
from sklearn.cross_validation import StratifiedKFold as KFold
from sklearn.metrics import classification_report
from matplotlib import pyplot as plt
from matplotlib import colors
from pylab import cm
from skimage import segmentation
from skimage.morphology import watershed
from skimage import measure
from skimage import morphology
import numpy as np
import pandas as pd
from scipy import ndimage
from skimage.feature import peak_local_max
from sklearn import tree
# make graphics inline
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# get the classnames from the directory structure
directory_names = list(set(glob.glob(os.path.join("C:\Users\E\Desktop\Zoology_kaggle","train", "*"))\
 ).difference(set(glob.glob(os.path.join("C:\Users\E\Desktop\Zoology_kaggle","train","*.*")))))

# %%
# Example image
# This example was chosen for because it has two noncontinguous pieces
# that will make the segmentation example more illustrative
example_file = glob.glob(os.path.join(directory_names[51],"*.jpg"))[11]
print example_file
im = imread(example_file, as_grey=True)
plt.imshow(im, cmap=cm.gray)
plt.show()
# Out:
# C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_h15\146671.jpg

# %%
# First we threshold the image by only taking values greater than the mean to reduce noise in the image
# to use later as a mask
f = plt.figure(figsize=(12,3))
imthr = im.copy()
imthr = np.where(im > np.mean(im),0.,1.0)
sub1 = plt.subplot(1,4,1)
plt.imshow(im, cmap=cm.gray)
sub1.set_title("Original Image")

sub2 = plt.subplot(1,4,2)
plt.imshow(imthr, cmap=cm.gray_r)
sub2.set_title("Thresholded Image")

imdilated = morphology.dilation(imthr, np.ones((4,4)))
sub3 = plt.subplot(1, 4, 3)
plt.imshow(imdilated, cmap=cm.gray_r)
sub3.set_title("Dilated Image")

#Label images based on connectedness.  Assign a number to each group.
labels = measure.label(imdilated)
labels = imthr*labels
labels = labels.astype(int)
sub4 = plt.subplot(1, 4, 4)
sub4.set_title("Labeled Image")
plt.imshow(labels)

# %%
# calculate common region properties for each region within the segmentation
regions = measure.regionprops(labels)
# find the largest nonzero region
def getLargestRegion(props=regions, labelmap=labels, imagethres=imthr):
    regionmaxprop = None
    for regionprop in props:
        # check to see if the region is at least 50% nonzero
        if sum(imagethres[labelmap == regionprop.label])*1.0/regionprop.area < 0.50:
            continue
        if regionmaxprop is None:
            regionmaxprop = regionprop
        if regionmaxprop.filled_area < regionprop.filled_area:
            regionmaxprop = regionprop
    return regionmaxprop

# %%
regionmax = getLargestRegion()
plt.imshow(np.where(labels == regionmax.label,1.0,0.0))
plt.show()

# %%
print regionmax.minor_axis_length/regionmax.major_axis_length
# Out:
# 0.593326586027

# %%
def getMinorMajorRatio(image):
    image = image.copy()
    # Create the thresholded image to eliminate some of the background
    imagethr = np.where(image > np.mean(image),0.,1.0)

    #Dilate the image
    imdilated = morphology.dilation(imagethr, np.ones((4,4)))

    # Create the label list
    label_list = measure.label(imdilated)
    label_list = imagethr*label_list
    label_list = label_list.astype(int)
    
    region_list = measure.regionprops(label_list)
    maxregion = getLargestRegion(region_list, label_list, imagethr)
    
    # guard against cases where the segmentation fails by providing zeros
    ratio = 0.0
    if ((not maxregion is None) and  (maxregion.major_axis_length != 0.0)):
        ratio = 0.0 if maxregion is None else  maxregion.minor_axis_length*1.0 / maxregion.major_axis_length
    return ratio

# %%
# Rescale the images and create the combined metrics and training labels

#get the total training images
numberofImages = 0
for folder in directory_names:
    for fileNameDir in os.walk(folder):   
        for fileName in fileNameDir[2]:
             # Only read in the images
            if fileName[-4:] != ".jpg":
              continue
            numberofImages += 1

# We'll rescale the images to be 25x25
maxPixel = 25
imageSize = maxPixel * maxPixel
num_rows = numberofImages # one row for each image in the training dataset
num_features = imageSize + 1 # for our ratio

# X is the feature vector with one row of features per image
# consisting of the pixel values and our metric
X = np.zeros((num_rows, num_features), dtype=float)
# y is the numeric class label 
y = np.zeros((num_rows))

files = []
# Generate training data
i = 0    
label = 0
# List of string of class names
namesClasses = list()

print "Reading images"
# Navigate through the list of directories
for folder in directory_names:
    # Append the string class name for each class
    currentClass = folder.split(os.pathsep)[-1]
    namesClasses.append(currentClass)
    for fileNameDir in os.walk(folder):   
        for fileName in fileNameDir[2]:
            # Only read in the images
            if fileName[-4:] != ".jpg":
              continue
            
            # Read in the images and create the features
            nameFileImage = "{0}{1}{2}".format(fileNameDir[0], os.sep, fileName)            
            image = imread(nameFileImage, as_grey=True)
            files.append(nameFileImage)
            axisratio = getMinorMajorRatio(image)
            image = resize(image, (maxPixel, maxPixel))
            
            # Store the rescaled image pixels and the axis ratio
            X[i, 0:imageSize] = np.reshape(image, (1, imageSize))
            X[i, imageSize] = axisratio
            
            # Store the classlabel
            y[i] = label
            i += 1
            # report progress for each 5% done  
            report = [int((j+1)*num_rows/20.) for j in range(20)]
            if i in report: print np.ceil(i *100.0 / num_rows), "% done"
    label += 1
# Out:
# Reading images
# 5.0
#  % done
# 10.0
#  % done
# 15.0
#  % done
# 20.0
#  % done
# 25.0
#  % done
# 30.0
#  % done
# 35.0
#  % done
# 40.0
#  % done
# 45.0
#  % done
# 50.0
#  % done
# 55.0
#  % done
# 60.0
#  % done
# 65.0
#  % done
# 70.0
#  % done
# 75.0
#  % done
# 80.0
#  % done
# 85.0
#  % done
# 90.0
#  % done
# 95.0
#  % done
# 100.0
#  % done

# %%
plt.hist(X[:,-1], bins=100)
# Out:
# (array([ 310.,    0.,    2.,   14.,   38.,   70.,  165.,  302.,  567.,
#          670.,  659.,  550.,  422.,  407.,  348.,  288.,  342.,  353.,
#          319.,  361.,  351.,  346.,  385.,  347.,  369.,  356.,  378.,
#          380.,  372.,  350.,  379.,  371.,  379.,  337.,  334.,  330.,
#          324.,  337.,  317.,  333.,  312.,  294.,  323.,  313.,  323.,
#          333.,  284.,  298.,  310.,  303.,  291.,  298.,  318.,  307.,
#          315.,  314.,  325.,  365.,  337.,  303.,  379.,  381.,  367.,
#          402.,  405.,  386.,  421.,  420.,  518.,  456.,  458.,  472.,
#          449.,  447.,  435.,  418.,  412.,  378.,  364.,  313.,  287.,
#          279.,  253.,  222.,  200.,  179.,  172.,  166.,  125.,  120.,
#           88.,   90.,   85.,   74.,   62.,   49.,   25.,   21.,   20.,    8.]),
#  array([ 0.        ,  0.00997431,  0.01994862,  0.02992293,  0.03989724,
#          0.04987155,  0.05984586,  0.06982016,  0.07979447,  0.08976878,
#          0.09974309,  0.1097174 ,  0.11969171,  0.12966602,  0.13964033,
#          0.14961464,  0.15958895,  0.16956326,  0.17953757,  0.18951188,
#          0.19948619,  0.20946049,  0.2194348 ,  0.22940911,  0.23938342,
#          0.24935773,  0.25933204,  0.26930635,  0.27928066,  0.28925497,
#          0.29922928,  0.30920359,  0.3191779 ,  0.32915221,  0.33912652,
#          0.34910082,  0.35907513,  0.36904944,  0.37902375,  0.38899806,
#          0.39897237,  0.40894668,  0.41892099,  0.4288953 ,  0.43886961,
#          0.44884392,  0.45881823,  0.46879254,  0.47876685,  0.48874115,
#          0.49871546,  0.50868977,  0.51866408,  0.52863839,  0.5386127 ,
#          0.54858701,  0.55856132,  0.56853563,  0.57850994,  0.58848425,
#          0.59845856,  0.60843287,  0.61840718,  0.62838148,  0.63835579,
#          0.6483301 ,  0.65830441,  0.66827872,  0.67825303,  0.68822734,
#          0.69820165,  0.70817596,  0.71815027,  0.72812458,  0.73809889,
#          0.7480732 ,  0.75804751,  0.76802181,  0.77799612,  0.78797043,
#          0.79794474,  0.80791905,  0.81789336,  0.82786767,  0.83784198,
#          0.84781629,  0.8577906 ,  0.86776491,  0.87773922,  0.88771353,
#          0.89768784,  0.90766214,  0.91763645,  0.92761076,  0.93758507,
#          0.94755938,  0.95753369,  0.967508  ,  0.97748231,  0.98745662,
#          0.99743093]),
#  <a list of 100 Patch objects>)

# %%
# Loop through the classes two at a time and compare their distributions of the Width/Length Ratio

#Create a DataFrame object to make subsetting the data on the class 
df = pd.DataFrame({"class": y[:], "ratio": X[:, num_features-1]})

f = plt.figure(figsize=(30, 20))
#we suppress zeros and choose a few large classes to better highlight the distributions.
df = df.loc[df["ratio"] > 0]
minimumSize = 20 
counts = df["class"].value_counts()
largeclasses = [int(x) for x in list(counts.loc[counts > minimumSize].index)]
# Loop through 40 of the classes 
for j in range(0,40,2):
    subfig = plt.subplot(4, 5, j/2 +1)
    # Plot the normalized histograms for two classes
    classind1 = largeclasses[j]
    classind2 = largeclasses[j+1]
    n, bins,p = plt.hist(df.loc[df["class"] == classind1]["ratio"].values,\
                         alpha=0.5, bins=[x*0.01 for x in range(100)], \
                         label=namesClasses[classind1].split(os.sep)[-1], normed=1)

    n2, bins,p = plt.hist(df.loc[df["class"] == (classind2)]["ratio"].values,\
                          alpha=0.5, bins=bins, label=namesClasses[classind2].split(os.sep)[-1],normed=1)
    subfig.set_ylim([0.,10.])
    plt.legend(loc='upper right')
    plt.xlabel("Width/Length Ratio")

# %%
print "Training"
# n_estimators is the number of decision trees
# max_features also known as m_try is set to the default value of the square root of the number of features
clf = RF(n_estimators=200, n_jobs=3);
scores = cross_validation.cross_val_score(clf, X, y, cv=5, n_jobs=1);
print "Accuracy of all classes"
print np.mean(scores)
# Out:
# Training
# Accuracy of all classes
# 0.478061941256

# %%
plt.plot(clf.feature_importances_)

# %%
kf = KFold(y, n_folds=5)
y_pred = y * 0
for train, test in kf:
    X_train, X_test, y_train, y_test = X[train,:], X[test,:], y[train], y[test]
    clf = RF(n_estimators=100, n_jobs=3)
    clf.fit(X_train, y_train)
    y_pred[test] = clf.predict(X_test)
print classification_report(y, y_pred, target_names=namesClasses)
# Out:
#                                                                                        precision    recall  f1-score   support
#
#           C:\Users\E\Desktop\Zoology_kaggle\train\copepod_calanoid
:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_typeD_bell_and_tentacles       0.67      0.04      0.07        56
#                                  C:\Users\E\Desktop\Zoology_kaggle\train\fecal_pellet       0.31      0.28      0.30       511
#                                        C:\Users\E\Desktop\Zoology_kaggle\train\ephyra       1.00      0.07      0.13        14
#                       C:\Users\E\Desktop\Zoology_kaggle\train\tunicate_doliolid_nurse       0.28      0.06      0.10       417
#                             C:\Users\E\Desktop\Zoology_kaggle\train\euphausiids_young       0.00      0.00      0.00        38
#                           C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_shapeB       0.21      0.04      0.07       150
#                           C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_shapeA       0.47      0.74      0.57       412
#                C:\Users\E\Desktop\Zoology_kaggle\train\copepod_cyclopoid_oithona_eggs       0.56      0.78      0.66      1189
#                     C:\Users\E\Desktop\Zoology_kaggle\train\unknown_blobs_and_smudges       0.23      0.14      0.17       317
#                       C:\Users\E\Desktop\Zoology_kaggle\train\fish_larvae_medium_body       0.49      0.26      0.34        85
# C:\Users\E\Desktop\Zoology_kaggle\train\siphonophore_calycophoran_sphaeronectes_young       0.50      0.07      0.12       247
#                             C:\Users\E\Desktop\Zoology_kaggle\train\radiolarian_chain       0.52      0.05      0.09       287
#                       C:\Users\E\Desktop\Zoology_kaggle\train\acantharia_protist_halo       0.67      0.03      0.05        71
#                             C:\Users\E\Desktop\Zoology_kaggle\train\shrimp-like_other       0.00      0.00      0.00        52
#                            C:\Users\E\Desktop\Zoology_kaggle\train\trochophore_larvae       0.00      0.00      0.00        29
#                               C:\Users\E\Desktop\Zoology_kaggle\train\shrimp_caridean       0.62      0.20      0.31        49
#       C:\Users\E\Desktop\Zoology_kaggle\train\siphonophore_calycophoran_sphaeronectes       0.66      0.13      0.21       179
#                          C:\Users\E\Desktop\Zoology_kaggle\train\tunicate_salp_chains       0.25      0.01      0.03        73
#                 C:\Users\E\Desktop\Zoology_kaggle\train\ctenophore_cydippid_tentacles       0.00      0.00      0.00        53
#                  C:\Users\E\Desktop\Zoology_kaggle\train\appendicularian_slight_curve       0.39      0.41      0.40       532
#                             C:\Users\E\Desktop\Zoology_kaggle\train\chaetognath_other       0.42      0.73      0.53      1934
#                          C:\Users\E\Desktop\Zoology_kaggle\train\trichodesmium_bowtie       0.49      0.66      0.56       708
#  C:\Users\E\Desktop\Zoology_kaggle\train\siphonophore_calycophoran_sphaeronectes_stem       0.00      0.00      0.00        57
#                                C:\Users\E\Desktop\Zoology_kaggle\train\chordate_type1       0.50      0.51      0.50        77
#                          C:\Users\E\Desktop\Zoology_kaggle\train\detritus_filamentous       0.14      0.01      0.02       394
#                     C:\Users\E\Desktop\Zoology_kaggle\train\copepod_calanoid_octomoms       0.00      0.00      0.00        49
#                          C:\Users\E\Desktop\Zoology_kaggle\train\siphonophore_partial       0.00      0.00      0.00        30
#                             C:\Users\E\Desktop\Zoology_kaggle\train\ctenophore_lobate       0.81      0.55      0.66        38
#                                 C:\Users\E\Desktop\Zoology_kaggle\train\copepod_other       0.00      0.00      0.00        24
#                           C:\Users\E\Desktop\Zoology_kaggle\train\protist_dark_center       0.00      0.00      0.00       108
#                            C:\Users\E\Desktop\Zoology_kaggle\train\acantharia_protist       0.46      0.83      0.59       889
#                            C:\Users\E\Desktop\Zoology_kaggle\train\trichodesmium_puff       0.73      0.93      0.82      1979
#                        C:\Users\E\Desktop\Zoology_kaggle\train\trichodesmium_multiple       0.83      0.09      0.17        54
#
#                                                                           avg / total       0.44      0.47      0.41     30334

# %%
#Make a decision tree about the X and y inputs.
clf_tree = tree.DecisionTreeClassifier()
clf_tree = clf_tree.fit(X,y)

# %%
kf = KFold(y, n_folds=5)
y_pred = y * 0
for train, test in kf:
    X_train, X_test, y_train, y_test = X[train,:], X[test,:], y[train], y[test]
    clf_tree = tree.DecisionTreeClassifier()
    clf_tree.fit(X_train, y_train)
    y_pred[test] = clf_tree.predict(X_test)
print classification_report(y, y_pred, target_names=namesClasses)
# Out:
#                                                                                        precision    recall  f1-score   support
#
#           C:\Users\E\Desktop\Zoology_kaggle\train\copepod_calanoid_small_longantennae       0.09      0.08      0.08        87
#                 C:\Users\E\Desktop\Zoology_kaggle\train\appendicularian_fritillaridae       0.00      0.00      0.00        16
#                      C:\Users\E\Desktop\Zoology_kaggle\train\siphonophore_other_parts       0.00      0.00      0.00        29
#                      C:\Users\E\Desktop\Zoology_kaggle\train\appendicularian_straight       0.06      0.06      0.06       242
#                C:\Users\E\Desktop\Zoology_kaggle\train\echinoderm_larva_pluteus_early       0.18      0.20      0.19        92
#            C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_shapeA_sideview_small       0.10      0.12      0.11       274
#                          C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_liriope       0.00      0.00      0.00        19
#                           C:\Users\E\Desktop\Zoology_kaggle\train\chaetognath_sagitta       0.25      0.24      0.24       694
#                                     C:\Users\E\Desktop\Zoology_kaggle\train\heteropod       0.00      0.00      0.00        10
#                       C:\Users\E\Desktop\Zoology_kaggle\train\chaetognath_non_sagitta       0.49      0.47      0.48       815
#                           C:\Users\E\Desktop\Zoology_kaggle\train\diatom_chain_string       0.47      0.51      0.49       519
#                              C:\Users\E\Desktop\Zoology_kaggle\train\copepod_calanoid       0.22      0.24      0.23       681
#                                     C:\Users\E\Desktop\Zoology_kaggle\train\artifacts       0.26      0.23      0.24       393
#                                     C:\Users\E\Desktop\Zoology_kaggle\train\amphipods       0.06      0.06      0.06        49
#                        C:\Users\E\Desktop\Zoology_kaggle\train\copepod_calanoid_large       0.21      0.22      0.21       286
#     C:\Users\E\Desktop\Zoology_kaggle\train\copepod_calanoid_large_side_antennatucked       0.12      0.13      0.13       106
#                             C:\Users\E\Desktop\Zoology_kaggle\train\ctenophore_cestid       0.09      0.06      0.07       113
#                        C:\Users\E\Desktop\Zoology_kaggle\train\pteropod_theco_dev_seq       0.00      0.00      0.00        13
#    C:\Users\E\Desktop\Zoology_kaggle\train\siphonophore_calycophoran_rocketship_young       0.12      0.11      0.12       483
#                            C:\Users\E\Desktop\Zoology_kaggle\train\shrimp_sergestidae       0.06      0.05      0.06       153
#                                      C:\Users\E\Desktop\Zoology_kaggle\train\decapods       0.00      0.00      0.00        55
#                                 C:\Users\E\Desktop\Zoology_kaggle\train\echinopluteus       0.06      0.04      0.05        27
#               C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_bell_and_tentacles       0.02      0.01      0.02        75
#                       C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_narco_dark       0.00      0.00      0.00        23
#         C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_haliscera_small_sideview       0.00      0.00      0.00         9
#                          C:\Users\E\Desktop\Zoology_kaggle\train\unknown_unclassified       0.03      0.03      0.03       425
#                             C:\Users\E\Desktop\Zoology_kaggle\train\pteropod_triangle       0.09      0.08      0.08        65
#                            C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_other       0.00      0.00      0.00        12
#                          C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_aglaura       0.02      0.02      0.02       127
#                   C:\Users\E\Desktop\Zoology_kaggle\train\invertebrate_larvae_other_A       0.00      0.00      0.00        14
#                   C:\Users\E\Desktop\Zoology_kaggle\train\invertebrate_larvae_other_B       0.05      0.04      0.05        24
#            C:\Users\E\Desktop\Zoology_kaggle\train\siphonophore_calycophoran_abylidae       0.05      0.05      0.05       212
#                C:\Users\E\Desktop\Zoology_kaggle\train\echinoderm_larva_pluteus_typeC       0.05      0.05      0.05        80
#                     C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_sideview_big       0.07      0.05      0.06        76
#                        C:\Users\E\Desktop\Zoology_kaggle\train\fish_larvae_myctophids       0.22      0.25      0.24       114
#                      C:\Users\E\Desktop\Zoology_kaggle\train\fish_larvae_leptocephali       0.00      0.00      0.00        31
#                         C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_solmaris       0.22      0.20      0.21       703
#                                   C:\Users\E\Desktop\Zoology_kaggle\train\euphausiids       0.17      0.17      0.17       136
#               C:\Users\E\Desktop\Zoology_kaggle\train\echinoderm_larva_pluteus_urchin       0.07      0.08      0.08        88
#                 C:\Users\E\Desktop\Zoology_kaggle\train\acantharia_protist_big_center       0.00      0.00      0.00        13
#                              C:\Users\E\Desktop\Zoology_kaggle\train\crustacean_other       0.10      0.11      0.11       201
#    C:\Users\E\Desktop\Zoology_kaggle\train\siphonophore_calycophoran_rocketship_adult       0.08      0.08      0.08       135
#          C:\Users\E\Desktop\Zoology_kaggle\train\echinoderm_larva_pluteus_brittlestar       0.13      0.19      0.15        36
#                                C:\Users\E\Desktop\Zoology_kaggle\train\artifacts_edge       0.58      0.49      0.53       170
#                    C:\Users\E\Desktop\Zoology_kaggle\train\copepod_calanoid_flatheads       0.07      0.08      0.07       178
#                        C:\Users\E\Desktop\Zoology_kaggle\train\siphonophore_physonect       0.01      0.01      0.01       128
#                      C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_narco_young       0.05      0.04      0.05       336
#                                    C:\Users\E\Desktop\Zoology_kaggle\train\stomatopod       0.00      0.00      0.00        24
#                                C:\Users\E\Desktop\Zoology_kaggle\train\unknown_sticks       0.07      0.08      0.07       175
#                     C:\Users\E\Desktop\Zoology_kaggle\train\copepod_cyclopoid_oithona       0.33      0.36      0.34       899
#         C:\Users\E\Desktop\Zoology_kaggle\train\echinoderm_larva_seastar_brachiolaria       0.40      0.38      0.39       536
#                              C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_h15       0.00      0.00      0.00        35
#               C:\Users\E\Desktop\Zoology_kaggle\train\copepod_calanoid_frillyAntennae       0.13      0.13      0.13        63
#                                 C:\Users\E\Desktop\Zoology_kaggle\train\protist_other       0.33      0.36      0.34      1172
#                    C:\Users\E\Desktop\Zoology_kaggle\train\copepod_calanoid_eucalanus       0.04      0.04      0.04        96
#                         C:\Users\E\Desktop\Zoology_kaggle\train\fish_larvae_deep_body       0.00      0.00      0.00        10
#                     C:\Users\E\Desktop\Zoology_kaggle\train\copepod_cyclopoid_copilia       0.06      0.03      0.04        30
#                           C:\Users\E\Desktop\Zoology_kaggle\train\protist_fuzzy_olive       0.48      0.47      0.47       372
#                       C:\Users\E\Desktop\Zoology_kaggle\train\appendicularian_s_shape       0.19      0.18      0.18       694
#                                    C:\Users\E\Desktop\Zoology_kaggle\train\polychaete       0.01      0.01      0.01       131
#                             C:\Users\E\Desktop\Zoology_kaggle\train\tunicate_doliolid       0.12      0.12      0.12       439
#                            C:\Users\E\Desktop\Zoology_kaggle\train\trichodesmium_tuft       0.23      0.24      0.24       678
#                             C:\Users\E\Desktop\Zoology_kaggle\train\diatom_chain_tube       0.21      0.25      0.23       500
#      C:\Users\E\Desktop\Zoology_kaggle\train\echinoderm_seacucumber_auricularia_larva       0.04      0.04      0.04        96
#              C:\Users\E\Desktop\Zoology_kaggle\train\ctenophore_cydippid_no_tentacles       0.00      0.00      0.00        42
#                     C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_narcomedusae       0.03      0.03      0.03       132
#                             C:\Users\E\Desktop\Zoology_kaggle\train\jellies_tentacles       0.06      0.05      0.06       141
#                                 C:\Users\E\Desktop\Zoology_kaggle\train\tunicate_salp       0.41      0.40      0.40       236
#                      C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_solmundella       0.05      0.06      0.05       123
#                                  C:\Users\E\Desktop\Zoology_kaggle\train\protist_star       0.22      0.28      0.25       113
#                            C:\Users\E\Desktop\Zoology_kaggle\train\pteropod_butterfly       0.01      0.01      0.01       108
#                  C:\Users\E\Desktop\Zoology_kaggle\train\siphonophore_physonect_young       0.00      0.00      0.00        21
#           C:\Users\E\Desktop\Zoology_kaggle\train\echinoderm_larva_seastar_bipinnaria       0.27      0.29      0.28       385
#                             C:\Users\E\Desktop\Zoology_kaggle\train\protist_noctiluca       0.33      0.32      0.33       625
#                            C:\Users\E\Desktop\Zoology_kaggle\train\radiolarian_colony       0.09      0.08      0.09       158
#                        C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_haliscera       0.27      0.24      0.25       229
#                     C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_partial_dark       0.27      0.23      0.25       190
#                         C:\Users\E\Desktop\Zoology_kaggle\train\fish_larvae_thin_body       0.05      0.05      0.05        64
#                    C:\Users\E\Desktop\Zoology_kaggle\train\fish_larvae_very_thin_body       0.00      0.00      0.00        16
#                                 C:\Users\E\Desktop\Zoology_kaggle\train\detritus_blob       0.08      0.09      0.09       363
#                            C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_typeF       0.14      0.08      0.10        61
#                         C:\Users\E\Desktop\Zoology_kaggle\train\copepod_calanoid_eggs       0.11      0.12      0.11       173
#                            C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_typeD       0.07      0.05      0.06        43
#                            C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_typeE       0.00      0.00      0.00        14
#                    C:\Users\E\Desktop\Zoology_kaggle\train\tornaria_acorn_worm_larvae       0.33      0.26      0.29        38
#                                C:\Users\E\Desktop\Zoology_kaggle\train\detritus_other       0.11      0.11      0.11       914
#                              C:\Users\E\Desktop\Zoology_kaggle\train\tunicate_partial       0.65      0.61      0.63       352
#                                   C:\Users\E\Desktop\Zoology_kaggle\train\shrimp_zoea       0.05      0.05      0.05       174
#         C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_typeD_bell_and_tentacles       0.07      0.05      0.06        56
#                                  C:\Users\E\Desktop\Zoology_kaggle\train\fecal_pellet       0.17      0.18      0.17       511
#                                        C:\Users\E\Desktop\Zoology_kaggle\train\ephyra       0.20      0.14      0.17        14
#                       C:\Users\E\Desktop\Zoology_kaggle\train\tunicate_doliolid_nurse       0.07      0.06      0.07       417
#                             C:\Users\E\Desktop\Zoology_kaggle\train\euphausiids_young       0.05      0.05      0.05        38
#                           C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_shapeB       0.07      0.07      0.07       150
#                           C:\Users\E\Desktop\Zoology_kaggle\train\hydromedusae_shapeA       0.31      0.28      0.29       412
#                C:\Users\E\Desktop\Zoology_kaggle\train\copepod_cyclopoid_oithona_eggs       0.45      0.48      0.47      1189
#                     C:\Users\E\Desktop\Zoology_kaggle\train\unknown_blobs_and_smudges       0.09      0.10      0.09       317
#                       C:\Users\E\Desktop\Zoology_kaggle\train\fish_larvae_medium_body       0.24      0.21      0.22        85
# C:\Users\E\Desktop\Zoology_kaggle\train\siphonophore_calycophoran_sphaeronectes_young       0.04      0.04      0.04       247
#                             C:\Users\E\Desktop\Zoology_kaggle\train\radiolarian_chain       0.07      0.07      0.07       287
#                       C:\Users\E\Desktop\Zoology_kaggle\train\acantharia_protist_halo       0.03      0.04      0.04        71
#                             C:\Users\E\Desktop\Zoology_kaggle\train\shrimp-like_other       0.00      0.00      0.00        52
#                            C:\Users\E\Desktop\Zoology_kaggle\train\trochophore_larvae       0.00      0.00      0.00        29
#                               C:\Users\E\Desktop\Zoology_kaggle\train\shrimp_caridean       0.06      0.04      0.05        49
#       C:\Users\E\Desktop\Zoology_kaggle\train\siphonophore_calycophoran_sphaeronectes       0.12      0.10      0.11       179
#                          C:\Users\E\Desktop\Zoology_kaggle\train\tunicate_salp_chains       0.04      0.03      0.03        73
#                 C:\Users\E\Desktop\Zoology_kaggle\train\ctenophore_cydippid_tentacles       0.00      0.00      0.00        53
#                  C:\Users\E\Desktop\Zoology_kaggle\train\appendicularian_slight_curve       0.18      0.19      0.18       532
#                             C:\Users\E\Desktop\Zoology_kaggle\train\chaetognath_other       0.44      0.44      0.44      1934
#                          C:\Users\E\Desktop\Zoology_kaggle\train\trichodesmium_bowtie       0.29      0.28      0.29       708
#  C:\Users\E\Desktop\Zoology_kaggle\train\siphonophore_calycophoran_sphaeronectes_stem       0.00      0.00      0.00        57
#                                C:\Users\E\Desktop\Zoology_kaggle\train\chordate_type1       0.30      0.27      0.29        77
#                          C:\Users\E\Desktop\Zoology_kaggle\train\detritus_filamentous       0.03      0.03      0.03       394
#                     C:\Users\E\Desktop\Zoology_kaggle\train\copepod_calanoid_octomoms       0.02      0.02      0.02        49
#                          C:\Users\E\Desktop\Zoology_kaggle\train\siphonophore_partial       0.00      0.00      0.00        30
#                             C:\Users\E\Desktop\Zoology_kaggle\train\ctenophore_lobate       0.32      0.32      0.32        38
#                                 C:\Users\E\Desktop\Zoology_kaggle\train\copepod_other       0.00      0.00      0.00        24
#                           C:\Users\E\Desktop\Zoology_kaggle\train\protist_dark_center       0.04      0.05      0.04       108
#                            C:\Users\E\Desktop\Zoology_kaggle\train\acantharia_protist       0.37      0.38      0.37       889
#                            C:\Users\E\Desktop\Zoology_kaggle\train\trichodesmium_puff       0.77      0.77      0.77      1979
#                        C:\Users\E\Desktop\Zoology_kaggle\train\trichodesmium_multiple       0.06      0.04      0.05        54
#
#                                                                           avg / total       0.27      0.27      0.27     30334

# %%
plot(clf_tree.feature_importances_)

# %%
clf_tree.predict(X)
scores = cross_validation.cross_val_score(clf_tree, X, y, cv=5, n_jobs=1);

# %%
print scores
# Out:
# [ 0.2711809   0.26838477  0.26947785  0.27183984  0.27906203]
